# %% [markdown]
# <a href="https://colab.research.google.com/github/chiraswykj/Machine_learning_2_lab/blob/main/ML2_Exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("student_data.csv")

# %%
df.head()
# Out:
#    student_ID  Name     Age  Gender  Study_Hours  Attendance  Assignments  \
# 0           1    19    Male     5.5           92         8.0           85
# 1           2    20  Female     7.0           95         9.0           91
# 2           3    18    Male     3.5           78         6.0           68
# 3           4    19  Female     6.0           88         8.0           82
# 4           5    21    Male     4.0           75         7.0           70
#
#   Exam_Score  Result
# 0       Pass     NaN
# 1       Pass     NaN
# 2       Pass     NaN
# 3       Pass     NaN
# 4       Pass     NaN

# %%
df.tail()
# Out:
#    student_ID  Name     Age  Gender  Study_Hours  Attendance  Assignments  \
# 5           6    20  Female     8.0           98        10.0           96
# 6           7    19    Male     NaN           85         7.0           76
# 7           8    18  Female     6.5           90         NaN           88
# 8           9    22    Male     2.5           65         5.0           60
# 9          10    20  Female     7.5           94         9.0           93
#
#   Exam_Score  Result
# 5       Fail     NaN
# 6       Pass     NaN
# 7       Pass     NaN
# 8       Pass     NaN
# 9       Fail     NaN

# %%
df.shape
# Out:
# (10, 9)

# %%
print(df.dtypes)
# Out:
# student_ID       int64
# Name             int64
# Age             object
# Gender         float64
# Study_Hours      int64
# Attendance     float64
# Assignments      int64
# Exam_Score      object
# Result         float64
# dtype: object

# %%
df.columns
# Out:
# Index(['student_ID', 'Name', 'Age', 'Gender', 'Study_Hours', 'Attendance',
#        'Assignments', 'Exam_Score', 'Result'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# student_ID      0
# Name            0
# Age             0
# Gender          1
# Study_Hours     0
# Attendance      1
# Assignments     0
# Exam_Score      0
# Result         10
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# student_ID     0
# Name           0
# Age            0
# Gender         0
# Study_Hours    0
# Attendance     0
# Assignments    0
# Exam_Score     0
# Result         0
# dtype: int64

# %%
df["Study_Hours"] = df["Study_Hours"].fillna(
    df["Study_Hours"].mean()
)

df["Attendance"] = df["Attendance"].fillna(
    df["Attendance"].mean()
)

df["Assignments"] = df["Assignments"].fillna(
    df["Assignments"].mean())
df = df.round(1)
print("\ndataset after replacing missing values:")
print(df)
# Out:
# dataset after replacing missing values:
# Empty DataFrame
# Columns: [student_ID, Name, Age, Gender, Study_Hours, Attendance, Assignments, Exam_Score, Result]
# Index: []

# %%
data = """Student_ID,Name,Age,Gender,Study_Hours,Attendance,Assignments,Exam_Score
1,Aarav,19,Male,5.5,92,8,85
2,Diya,20,Female,7.0,95,9,91
3,Rohan,18,Male,3.5,78,6,68
4,Ananya,19,Female,6.0,88,8,82
5,Vikram,21,Male,4.0,75,7,70
6,Meera,20,Female,8.0,98,10,96
7,Arjun,19,Male,,85,7,76
8,Sneha,18,Female,6.5,90,,88
9,Karan,22,Male,2.5,65,5,60
10,Ishita,20,Female,7.5,94,9,93
11,Rahul,21,Male,4.5,,6,72
12,Priya,19,Female,5.0,87,8,80
13,Aditya,20,Male,3.0,72,5,65
14,Nisha,18,Female,6.0,91,8,86
15,Manish,22,Male,4.0,80,7,74
16,Kavya,19,Female,8.5,99,10,98
17,Sameer,21,Male,5.5,89,8,81
18,Pooja,20,Female,7.0,93,9,90
19,Varun,18,Male,3.5,76,6,67
20,Neha,19,Female,6.5,88,8,84"""

with open("student_performance.csv", "w") as file:
    file.write(data)

df = pd.read_csv("student_performance.csv")

# %%
df["Study_Hours"] = df["Study_Hours"].fillna(
    df["Study_Hours"].mean()
)

df["Attendance"] = df["Attendance"].fillna(
    df["Attendance"].mean()
)

df["Assignments"] = df["Assignments"].fillna(
    df["Assignments"].mean())
df = df.round(1)
print("\ndataset after replacing missing values:")
print(df)
# Out:
# dataset after replacing missing values:
#     Student_ID    Name  Age  Gender  Study_Hours  Attendance  Assignments  \
# 0            1   Aarav   19    Male          5.5        92.0          8.0
# 1            2    Diya   20  Female          7.0        95.0          9.0
# 2            3   Rohan   18    Male          3.5        78.0          6.0
# 3            4  Ananya   19  Female          6.0        88.0          8.0
# 4            5  Vikram   21    Male          4.0        75.0          7.0
# 5            6   Meera   20  Female          8.0        98.0         10.0
# 6            7   Arjun   19    Male          5.5        85.0          7.0
# 7            8   Sneha   18  Female          6.5        90.0          7.6
# 8            9   Karan   22    Male          2.5        65.0          5.0
# 9           10  Ishita   20  Female          7.5        94.0          9.0
# 10          11   Rahul   21    Male          4.5        86.1          6.0
# 11          12   Priya   19  Female          5.0        87.0          8.0
# 12          13  Aditya   20    Male          3.0        72.0          5.0
# 13          14   Nisha   18  Female          6.0        91.0          8.0
# 14          15  Manish   22    Male          4.0        80.0          7.0
# 15          16   Kavya   19  Female          8.5        99.0         10.0
# 16          17  Sameer   21    Male          5.5        89.0          8.0
# 17          18   Pooja   20  Female          7.0        93.0          9.0
# 18          19   Varun   18    Male          3.5        76.0          6.0
# 19          20    Neha   19  Female          6.5        88.0          8.0
#
#     Exam_Score
# 0           85
# 1           91
# 2           68
# 3           82
# 4           70
# 5           96
# 6           76
# 7           88
# 8           60
# 9           93
# 10          72
# 11          80
# 12          65
# 13          86
# 14          74
# 15          98
# 16          81
# 17          90
# 18          67
# 19          84

# %%
df['Gender'].fillna(df['Gender'].mode()[0],inplace=True)
# Out:
# /tmp/ipykernel_6194/3554240144.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].fillna(df['Gender'].mode()[0],inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        Student_ID        Age  Study_Hours  Attendance  Assignments  Exam_Score
# count    20.00000  20.000000    20.000000   20.000000     20.00000   20.000000
# mean     10.50000  19.650000     5.475000   86.055000      7.58000   80.300000
# std       5.91608   1.268028     1.705062    9.063953      1.46237   10.926067
# min       1.00000  18.000000     2.500000   65.000000      5.00000   60.000000
# 25%       5.75000  19.000000     4.000000   79.500000      6.75000   71.500000
# 50%      10.50000  19.500000     5.500000   88.000000      8.00000   81.500000
# 75%      15.25000  20.250000     6.625000   92.250000      8.25000   88.500000
# max      20.00000  22.000000     8.500000   99.000000     10.00000   98.000000

# %%
print(df['Exam_Score'].mean())
print(df['Exam_Score'].median())
print(df['Exam_Score'].std())
print(df['Exam_Score'].min())
print(df['Exam_Score'].max())
# Out:
# 80.3
# 81.5
# 10.926067333145125
# 60
# 98

# %%
plt.hist(df['Exam_Score'],bins=10)
plt.xlabel("Exam_Score")
plt.ylabel("Frequency")
plt.title("distrubtion of marks")
plt.show()

# %%
plt.boxplot(df['Study_Hours'])
plt.ylabel("Study_Hours")
plt.title("box plot of study hours")
# Out:
# Text(0.5, 1.0, 'box plot of study hours')

# %%
corr = df.corr(numeric_only=True)
print(corr)
# Out:
#                Student_ID       Age  Study_Hours  Attendance   Assignments  \
# Student_ID   1.000000e+00  0.045603     0.024784   -0.023998  2.593561e-16
# Age          4.560337e-02  1.000000    -0.259863   -0.304593 -1.742724e-01
# Study_Hours  2.478368e-02 -0.259863     1.000000    0.944796  9.475421e-01
# Attendance  -2.399792e-02 -0.304593     0.944796    1.000000  9.198696e-01
# Assignments  2.593561e-16 -0.174272     0.947542    0.919870  1.000000e+00
# Exam_Score  -2.442698e-03 -0.265541     0.980753    0.962392  9.629057e-01
#
#              Exam_Score
# Student_ID    -0.002443
# Age           -0.265541
# Study_Hours    0.980753
# Attendance     0.962392
# Assignments    0.962906
# Exam_Score     1.000000

# %%
print(df.shape)
print(df.isnull().sum())
print(df.duplicated().sum())
# Out:
# (20, 8)
# Student_ID     0
# Name           0
# Age            0
# Gender         0
# Study_Hours    0
# Attendance     0
# Assignments    0
# Exam_Score     0
# dtype: int64
# 0
